# %% [markdown]
# <a href="https://colab.research.google.com/github/TejasShrestha/DATA201-labs/blob/main/Assignments/Week_2_HW_(Data_201).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WEEK 2 HW (DATA-201)**

# %%
#mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 8a.

# %%
#After you authorize access, load the dataset from your Datasets folder. Make sure the file path is correct
import pandas as pd

file_path = "/content/drive/MyDrive/DATA-201/Datasets/College.csv"

college = pd.read_csv(file_path)

college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# 8b.

# %%
college2 = pd.read_csv(file_path, index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'},
                          axis=1)
college3 = college3.set_index('College')

# %%
college = college3

# %% [markdown]
# 8c.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# 8d.

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# 8e.

# %%
college.boxplot(column='Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# 8f.

# %%
college['Elite'] = pd.cut(college['Top10perc'],
                          [0,0.5,1],
                          labels=['No','Yes'])

# %%
college.value_counts()
# Out:
# Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  Elite
# No       1455  1064    452     1          16         2632         617          6806      2550        350    766       75   75        15.1       10           6972    24         Yes      1
#          1563  1005    240     1          19         1380         136          5542      4330        500    1000      65   71        14.2       17           6562    57         Yes      1
# Yes      601   396     203     1          20         525          323          11230     6643        2340   620       8    58        6.8        4            13025   47         Yes      1
# Name: count, dtype: int64

# %%
college.boxplot(column='Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# 8g.

# %%
fig, ax = plt.subplots(2,2)
college['Apps'].plot.hist(ax=ax[0,0],bins=50)
college['Accept'].plot.hist(ax=ax[0,1],bins=100)
college['Enroll'].plot.hist(ax=ax[1,0],bins=25)
college['Grad.Rate'].plot.hist(ax=ax[1,1],bins=75)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 8h.

# %%
college.boxplot(column='Apps', by='Private')
# Out:
# <Axes: title={'center': 'Apps'}, xlabel='Private'>

# %%
college.boxplot(column='Accept', by='Private')
# Out:
# <Axes: title={'center': 'Accept'}, xlabel='Private'>

# %% [markdown]
# As I continued to explore the data, I discovered that that Public colleges had a far larger application rate compared to Private colleges through the first boxplot. Using this, we can conclude that private colleges have less applications than public colleges. We can also infer that private universities also have a smaller acceptance rate than public universities as shown in the second boxplot I created.

# %%
file_path = "/content/drive/MyDrive/DATA-201/Datasets/Auto.csv"

Auto = pd.read_csv(file_path)

Auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
Auto.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
Auto["horsepower"] = Auto["horsepower"].replace("?", pd.NA)

# %%
Auto["horsepower"] = pd.to_numeric(Auto["horsepower"])

# %% [markdown]
# 9a.
#
# Quantitative: mpg, displacement, horsepower, weight, & acceleration
#
# Qualitative: name, year, origin, & cylinders

# %% [markdown]
# 9b.

# %%
print(Auto['mpg'].min())
print(Auto['mpg'].max())
# Out:
# 9.0
# 46.6

# %%
print(Auto['displacement'].min())
print(Auto['displacement'].max())
# Out:
# 68.0
# 455.0

# %%
print(Auto['horsepower'].min())
print(Auto['horsepower'].max())
# Out:
# 46.0
# 230.0

# %%
print(Auto['weight'].min())
print(Auto['weight'].max())
# Out:
# 1613
# 5140

# %%
print(Auto['acceleration'].min())
print(Auto['acceleration'].max())
# Out:
# 8.0
# 24.8

# %% [markdown]
# 9c.

# %%
print(Auto['mpg'].mean())
print(Auto['mpg'].std())
# Out:
# 23.51586901763224
# 7.825803928946562

# %%
print(Auto['displacement'].mean())
print(Auto['displacement'].std())
# Out:
# 193.53274559193954
# 104.37958329992945

# %%
print(Auto['horsepower'].mean())
print(Auto['horsepower'].std())
# Out:
# 104.46938775510205
# 38.49115993282855

# %%
print(Auto['weight'].mean())
print(Auto['weight'].std())
# Out:
# 2970.2619647355164
# 847.9041194897246

# %%
print(Auto['acceleration'].mean())
print(Auto['acceleration'].std())
# Out:
# 15.55566750629723
# 2.7499952929761515

# %% [markdown]
# 9d.

# %%
Auto2 = Auto.drop(index=range(9, 85))
display(Auto2.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
print(Auto2['mpg'].max() - Auto2['mpg'].min())
print(Auto2['mpg'].mean())
print(Auto2['mpg'].std())
# Out:
# 35.6
# 24.438629283489096
# 7.908184248945195

# %%
print(Auto2['displacement'].max() - Auto2['displacement'].min())
print(Auto2['displacement'].mean())
print(Auto2['displacement'].std())
# Out:
# 387.0
# 187.04984423676012
# 99.63538531961508

# %%
print(Auto2['horsepower'].max() - Auto2['horsepower'].min())
print(Auto2['horsepower'].mean())
print(Auto2['horsepower'].std())
# Out:
# 184.0
# 100.95583596214512
# 35.89556677713123

# %%
print(Auto2['weight'].max() - Auto2['weight'].min())
print(Auto2['weight'].mean())
print(Auto2['weight'].std())
# Out:
# 3348
# 2933.96261682243
# 810.6429384125482

# %%
print(Auto2['acceleration'].max() - Auto2['acceleration'].min())
print(Auto2['acceleration'].mean())
print(Auto2['acceleration'].std())
# Out:
# 16.3
# 15.723052959501558
# 2.6805138313971697

# %% [markdown]
# 9e.

# %%
Auto2.boxplot(column='weight', by='cylinders')
# Out:
# <Axes: title={'center': 'weight'}, xlabel='cylinders'>

# %% [markdown]
# The weight typically increases as the # of cylinders increases with the only exception being cylinders with 3 and 4.

# %%
plt.hist(Auto2['mpg'])
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.title('Histogram of MPG')
# Out:
# Text(0.5, 1.0, 'Histogram of MPG')

# %% [markdown]
# In this histogram of MPG we can see that most cars in this dataset with the removal of observations 10 through 85 have the performance of between 15-20 mpg.

# %% [markdown]
# 9f.
#
# If we wish to predict gas mileage (mpg) on the basis of other variables none of the plots I created suggest that any of the variables might be useful in predicting mpg but I believe we can create one. We can make a graph that correlates mpg in relation to weight showing the relationship between the two variables.

# %% [markdown]
# 10a.

# %%
file_path = "/content/drive/MyDrive/DATA-201/Datasets/Boston.csv"

Boston = pd.read_csv(file_path)

Boston.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio  lstat  medv
# 0  296     15.3   4.98  24.0
# 1  242     17.8   9.14  21.6
# 2  242     17.8   4.03  34.7
# 3  222     18.7   2.94  33.4
# 4  222     18.7   5.33  36.2

# %% [markdown]
# 10b.

# %%
Boston.shape
# Out:
# (506, 14)

# %% [markdown]
# 506 Rows
#
# 14 Columns

# %% [markdown]
# 10c.

# %%
pd.plotting.scatter_matrix(boston[['crim', 'tax', 'age']])
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='tax', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='tax'>,
#         <Axes: xlabel='tax', ylabel='tax'>,
#         <Axes: xlabel='age', ylabel='tax'>],
#        [<Axes: xlabel='crim', ylabel='age'>,
#         <Axes: xlabel='tax', ylabel='age'>,
#         <Axes: xlabel='age', ylabel='age'>]], dtype=object)

# %% [markdown]
# In this plot we can see that when a variable is the same on both the y and x axis, we get a histogram of that variable. In all the other boxes where the variables are mixed, we obtain a scatterplot combining the two variables.

# %% [markdown]
# 10d.
#
# Yes, the crim predictor is assocaited with per capita crime rate as the numerical values for each observation is associated with the crime rate for that specific observation.

# %% [markdown]
# 10e.

# %%
print(boston['crim'].min())
print(boston['crim'].max())
print(boston['crim'].mean())
# Out:
# 0.00632
# 88.9762
# 3.613523557312254

# %% [markdown]
# Yes, 88.9% is a very high crime rate for a Boston suburb.

# %%
print(boston['tax'].min())
print(boston['tax'].max())
print(boston['tax'].mean())
# Out:
# 187
# 711
# 408.2371541501976

# %% [markdown]
# Yes, using the information I found, I believe anything over 625 is high tax rate.

# %%
print(boston['ptratio'].min())
print(boston['ptratio'].max())
print(boston['ptratio'].mean())
# Out:
# 12.6
# 22.0
# 18.455533596837945

# %% [markdown]
# Yes, using the information I found, I believe anything over 21 is high.

# %% [markdown]
# 10f.

# %%
print((boston['chas'] == 1).sum())
# Out:
# 35

# %% [markdown]
# 10g.

# %%
print(boston['ptratio'].median())
# Out:
# 19.05

# %% [markdown]
# 10h.

# %%
boston["medv"].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %%
boston.loc[boston["medv"] == 5]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %% [markdown]
# These are the two suburbs that have the lowest mediam value of owner-occupid homes along with the values of the other preodictors for that suburb. The crime rates are above average, the zn is slightly above average, the indus is slightly above average, the chas is the lowest, the nox is slightly below average, the rm is slightly above average, the age is the highest it can be, the dis is low, the rad is the highest, the tax is high, the pt ratio is high, and the lstat is high.

# %% [markdown]
# 10i.

# %%
print((boston['rm'] > 7).sum())
# Out:
# 64

# %%
print((boston['rm'] > 8).sum())
# Out:
# 13

# %%
boston.loc[boston["rm"] > 8]
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...

# %% [markdown]
# The last suburb number 364 has higher values than all of the others. For example the crime rates for all the vraibles are low but it is the highest for that section. The tax rate for suburg 364 is far higher than the rest witht eh value 666.
